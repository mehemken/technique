# %%
x = seq(-2, 2, .1)
y = x^2

plot(x, y, 'l')
# Out:
# plot without title

# %%
help('dev.copy2eps')

# %%
library(ggplot2)

# %%
df = data.frame(x, y)

# %%
head(df)
# Out:
#   x    y
# 1 -2.0 4.00
# 2 -1.9 3.61
# 3 -1.8 3.24
# 4 -1.7 2.89
# 5 -1.6 2.56
# 6 -1.5 2.25

# %%
ggplot(df, aes(x=df$x, y=df$y)) + geom_line()
# Out:
# plot without title

# %% [markdown]
# This is an integral.
#
# $$\int$$
#
# I left off on page 32.
